# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
from helper_functions import *

# %%
df = pd.read_csv('sheets/real_lexicons_fit_mu_0.2_pgs_0_0.789_-1.315num_dists_3.csv').drop(['r patterns', 'theta patterns', 'consistency_score'], axis=1)
df = df.drop(df.columns[0], axis=1)

# %%
consistency(df)
# Out:
# i =  1  /  220 ; lang =  	Kabiyé (Atlantic-Congo, Gur)
#      D1_place  D2_place  D3_place  D1_goal  D2_goal  D3_goal  D1_source  \
# 0           0         2         2        4        3        3          5
# 1           2         5         5        4        0        0          1
# 2           4         0         0        5        1        1          2
# 3           0         3         3        0        3        3          2
# 4           2         5         5        4        1        1          3
# 5           0         2         1        0        2        1          0
# 6           3         2         2        4        1        1          0
# 7           3         2         2        1        4        4          5
# 8           3         2         2        3        2        2          1
# 9           8         5         1        7        2        6          4
# 10          8         0         5        2        3        4          6
# ...

# %%
df
# Out:
#      D1_place  D2_place  D3_place  D1_goal  D2_goal  D3_goal  D1_source  \
# 0           0         2         2        4        3        3          5
# 1           2         5         5        4        0        0          1
# 2           4         0         0        5        1        1          2
# 3           0         3         3        0        3        3          2
# 4           2         5         5        4        1        1          3
# ..        ...       ...       ...      ...      ...      ...        ...
# 215         6         0         4        5        3        1          7
# 216         1         1         4        5        3        0          2
# 217         4         2         2        5        0        0          3
# 218         2         3         3        1        4        4          5
# 219         0         1         1        4        5        5          2
#
#      D2_source  D3_source    I[U;W]    I[M;W]  gamma_fit       epsilon  \
# ...
